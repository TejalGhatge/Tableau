# %% [markdown]
# # TABLEAU
#
# ### Feature :
# * Access to more than 77 data sources to extract data.
# * Ability to handle large data.
# * Real-time analysis.
# * Simple and User-friendly interface.
# * Ability to create interactive visualizations.
#
# These features make it easy to use Tableau and provide an appropriate way to channelize the story of the dataset.
#
# Following is the Link to my Tableau Public Profile.
#
# Tableau [LINK](http://public.tableau.com/app/profile/tejal.ghatge)

# %% [markdown]
# ### Some Interesting Stories :
#
# * [NETFLIX ENTERTAINMENT](https://public.tableau.com/app/profile/tejal.ghatge/viz/NetflixEntertainment/Dashboard1) : This explores the Netflix dataset and charts out interactive dashboard. Different tabs displayed with it provide step-by-step creation of it.
# * [SAN FRANCISCO AIRPORT](https://public.tableau.com/app/profile/tejal.ghatge/viz/SanFranciscoAirport_16394633368290/SanFranciscoAirport) : This dashboard explores the dataset related to the San Francisco Data. Also on the global platform, it shows the connected ways through a map chart. More information is provided using bars and line charts.

# %% [markdown]
# ### MANY MORE STORIES ON WAY....
